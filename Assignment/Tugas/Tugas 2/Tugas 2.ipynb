# %%
import imageio
import matplotlib .pyplot as plt
import numpy as np
# %matplotlib inline

img = imageio.imread("bird.jpeg").astype(np.float64)/255.0
plt.imshow(img)

r = img[:,:,0]
print(r)
plt.imshow(r, cmap='gray')
# Out:
# [[0.52156863 0.54117647 0.55294118 ... 0.41960784 0.41176471 0.40784314]
#  [0.52941176 0.53333333 0.53333333 ... 0.38431373 0.39607843 0.40392157]
#  [0.53333333 0.53333333 0.52941176 ... 0.35686275 0.39215686 0.41960784]
#  ...
#  [0.24705882 0.25098039 0.25882353 ... 0.30980392 0.32941176 0.3372549 ]
#  [0.24705882 0.25098039 0.25882353 ... 0.29019608 0.30980392 0.3254902 ]
#  [0.24705882 0.25098039 0.25098039 ... 0.2627451  0.29411765 0.31764706]]

# %%
import cv2 as cv

a= (np.ones(img2.shape, dtype='uint8') * 100)
img2= cv.imread('bird.jpeg').astype('uint8')
# cv.imshow('burung',img2)
# cv.waitKey(0)

plt.imshow(img2)
plt.show()

# %%
b, g, r= cv.split(img2)

plt.imshow(g, cmap='gray')
plt.show()

# %%
black= np.zeros(img.shape[:2], dtype='uint8')

fig, img2_plot= plt.subplots(nrows= 1, ncols= 3, figsize=(20,20))

just_green= cv.merge([black, g, black])
img2_plot[0].imshow(just_green)
img2_plot[0].set_title('g')

just_red= cv.merge([black, black, r])
img2_plot[1].imshow(just_red)
img2_plot[1].set_title('r')

just_blue= cv.merge([b, black, black])
img2_plot[2].imshow(just_blue)
img2_plot[2].set_title('b')

plt.show()

# %%
new_img2= cv.merge([r,g,b])
plt.imshow(new_img2)

# %%
new_img3= cv.cvtColor(cv.imread('bird.jpeg'), cv.COLOR_BGR2RGB)
plt.imshow(new_img3)
